# %%
import pickle
import pandas as pd

# Load the embeddings from the pickle file
with open('models_15jun/ta_paragraph_2/reference_embeddings.pkl', 'rb') as f:
    embeddings = pickle.load(f)

# Convert to DataFrame if it's not already one
if not isinstance(embeddings, pd.DataFrame):
    embeddings_df = pd.DataFrame(embeddings)
else:
    embeddings_df = embeddings

# Display the first few rows
print("Shape of embeddings:", embeddings_df.shape)
print("\nFirst few rows of embeddings:")
display(embeddings_df.head())
# Out:
# Shape of embeddings: (1, 3)
#
# First few rows of embeddings:
#                                            embeddings_std_par  \
# embeddings  [[0.09544864, -0.044462126, 0.06363079, -0.047...
#
#                                           embeddings_gpt1_par  \
# embeddings  [[-0.06903632, 0.037385754, -0.009174111, 0.03...
#
#                                           embeddings_gpt2_par
# embeddings  [[-0.0824619, 0.043940615, -0.030486241, 0.024...
